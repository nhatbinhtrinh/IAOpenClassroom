# %% [markdown]
# # Set up the Environment

# %%
#import library
import requests, uuid, json

# %%
# Subscription key 
subscription_key = "4a18acbf75914e27b218af2201059686"
# Endpoint
endpoint = "https://api.cognitive.microsofttranslator.com/"
# Location
location = "francecentral"

# %% [markdown]
# ## Translate Text

# %%
 # Translate from english to french (fr) and vietnamese (vi)
path = '/translate'    
params = {
    'api-version': '3.0',
    'from': 'en',
    'to': ['fr', 'vi']
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'Hello Everybody!'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "translations": [
#             {
#                 "text": "Bonjour à tous !",
#                 "to": "fr"
#             },
#             {
#                 "text": "Xin chào mọi người!",
#                 "to": "vi"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ## Detect language from the given text

# %% [markdown]
# ### Detect language with translate

# %%
path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'to' :['en','vi']
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'Salut tout de monde!'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "detectedLanguage": {
#             "language": "fr",
#             "score": 1.0
#         },
#         "translations": [
#             {
#                 "text": "Hi everyone!",
#                 "to": "en"
#             },
#             {
#                 "text": "Chào mọi người!",
#                 "to": "vi"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ### Detect without translate

# %%
path = '/detect'
constructed_url = endpoint + path

params = {
    'api-version': '3.0'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'Je voudrais un cafe!'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "isTranslationSupported": true,
#         "isTransliterationSupported": false,
#         "language": "fr",
#         "score": 1.0
#     }
# ]

# %% [markdown]
# ## Sentence Length

# %% [markdown]
#  ### Count character with translate

# %%
path = '/translate'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'to': ['en','vi'],
    'includeSentenceLength': True
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'J\'aimerais un chocolate chaud.'
}]
request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "detectedLanguage": {
#             "language": "fr",
#             "score": 1.0
#         },
#         "translations": [
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         30
#                     ],
#                     "transSentLen": [
#                         29
#                     ]
#                 },
#                 "text": "I would like a hot chocolate.",
#                 "to": "en"
#             },
#             {
#                 "sentLen": {
#                     "srcSentLen": [
#                         30
#                     ],
#                     "transSentLen": [
#                         27
#                     ]
#                 },
#                 "text": "Tôi muốn một sô cô la nóng.",
#                 "to": "vi"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ### Count character with translate

# %%
path = '/breaksentence'
constructed_url = endpoint + path

params = {
    'api-version': '3.0'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [{
    'text': 'Tôi muốn một sô cô la nóng.'
}]

request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "detectedLanguage": {
#             "language": "vi",
#             "score": 1.0
#         },
#         "sentLen": [
#             27
#         ]
#     }
# ]

# %% [markdown]
# ## Look up in Dictionary

# %%
path = '/dictionary/lookup'
constructed_url = endpoint + path

params = {
    'api-version': '3.0',
    'from': 'en',
    'to': 'vi'
}
constructed_url = endpoint + path

headers = {
    'Ocp-Apim-Subscription-Key': subscription_key,
    'Ocp-Apim-Subscription-Region': location,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
}

# You can pass more than one object in body.
body = [
    {"id1": 1, "text": "rice"},
    {"id1": 1, "text": "yellow"}
]
request = requests.post(constructed_url, params=params, headers=headers, json=body)
response = request.json()

print(json.dumps(response, sort_keys=True, ensure_ascii=False, indent=4, separators=(',', ': ')))
# Out:
# [
#     {
#         "displaySource": "rice",
#         "normalizedSource": "rice",
#         "translations": [
#             {
#                 "backTranslations": [
#                     {
#                         "displayText": "rice",
#                         "frequencyCount": 651,
#                         "normalizedText": "rice",
#                         "numExamples": 15
#                     }
#                 ],
#                 "confidence": 0.5166,
#                 "displayTarget": "gạo",
#                 "normalizedTarget": "gạo",
#                 "posTag": "NOUN",
#                 "prefixWord": ""
#             },
#             {
#                 "backTranslations": [
#                     {
#                         "displayText": "rice",
#                         "frequencyCount": 98,
#                         "normalizedText": "rice",
#                         "numExamples": 15
#                     },
#                     {
# ...
